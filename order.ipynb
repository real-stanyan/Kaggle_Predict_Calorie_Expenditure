# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/orders_export_1.csv')

data.head(5)
# Out:
#     Name Email Financial Status Paid at Fulfillment Status  \
# 0  #1282   NaN             paid     NaN        unfulfilled
# 1  #1281   NaN             paid     NaN        unfulfilled
# 2  #1280   NaN             paid     NaN          fulfilled
# 3  #1279   NaN             paid     NaN            partial
# 4  #1278   NaN             paid     NaN          fulfilled
#
#                 Fulfilled at Accepts Marketing Currency  Subtotal  Shipping  \
# 0                        NaN                no      AUD     212.0       0.0
# 1                        NaN                no      AUD     212.0       0.0
# 2  2025-05-13 13:37:30 +1000                no      AUD     106.0       0.0
# 3                        NaN                no      AUD     318.0       0.0
# 4  2025-05-12 12:38:22 +1000                no      AUD     318.0       0.0
#
#    ...  Tax 5 Value  Phone Receipt Number  Duties Billing Province Name  \
# 0  ...          NaN    NaN            NaN     NaN       New South Wales
# ...
